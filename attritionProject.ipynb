# %%
import pandas as pd

# %%
df = pd.read_csv("file:///C:/Users/OMKAR/Downloads/general_data.csv")

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df[['Age','MonthlyIncome','YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager','MonthlyIncome']].skew()
# Out:
# Age                        0.413005
# MonthlyIncome              1.368884
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# MonthlyIncome              1.368884
# dtype: float64

# %%
df[['Age','MonthlyIncome','YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager','MonthlyIncome']].kurt()
# Out:
# Age                       -0.405951
# MonthlyIncome              1.000232
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# MonthlyIncome              1.000232
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.boxplot(df.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16498181088>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1649817c4c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x164981975c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x164981240c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16497ba73c8>],
#  'means': []}

# %% [markdown]
#     1. Here we can find some outliers in MonthlyIncome column we can remove them

# %%
df.loc[df["Attrition"]=="Yes","Attrition"]=1
df.loc[df["Attrition"]=="No","Attrition"]=0

df.head(10)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51         0      Travel_Rarely                   Sales                 6
# 1   31         1  Travel_Frequently  Research & Development                10
# 2   32         0  Travel_Frequently  Research & Development                17
# 3   38         0         Non-Travel  Research & Development                 2
# 4   32         0      Travel_Rarely  Research & Development                10
# 5   46         0      Travel_Rarely  Research & Development                 8
# 6   28         1      Travel_Rarely  Research & Development                11
# 7   29         0      Travel_Rarely  Research & Development                18
# 8   31         0      Travel_Rarely  Research & Development                 1
# 9   25         0         Non-Travel  Research & Development                 7
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %% [markdown]
# Above we Change the attrition value yes,no By 1,0
#
#
# Now removing Outliers in MonthlyIncome

# %%
solution = df[df['MonthlyIncome']<175000]
solution.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51         0      Travel_Rarely                   Sales                 6
# 1   31         1  Travel_Frequently  Research & Development                10
# 3   38         0         Non-Travel  Research & Development                 2
# 4   32         0      Travel_Rarely  Research & Development                10
# 5   46         0      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# 5          3  Life Sciences              1           6  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
solution.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4167.000000       4167.000000  4167.000000         4167.0  4167.000000
# mean     36.963283          9.190785     2.908567            1.0  2204.751620
# std       9.115799          8.072126     1.027954            0.0  1273.714656
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1105.500000
# 50%      36.000000          7.000000     3.000000            1.0  2205.000000
# 75%      43.000000         14.000000     4.000000            1.0  3303.500000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4167.000000    4167.000000         4148.000000        4167.000000
# mean      2.053996   57755.284377            2.689971          15.208063
# ...

# %%
solution.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.004010  -0.039705            NaN
# DistanceFromHome         0.004010          1.000000  -0.013171            NaN
# Education               -0.039705         -0.013171   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.005482         -0.000937  -0.008888            NaN
# JobLevel                -0.009126         -0.039466   0.039339            NaN
# MonthlyIncome           -0.046044         -0.031016  -0.006555            NaN
# NumCompaniesWorked       0.298356         -0.021632  -0.012713            NaN
# PercentSalaryHike       -0.039987          0.033869  -0.050510            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.025509          0.005895   0.000773            NaN
# ...

# %%
from scify.stats import pearsonr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-9682e0c96692> in <module>
# ----> 1 from scify.stats import pearsonr
#
# ModuleNotFoundError: No module named 'scify'

# %%
import scipy

# %%
from scipy.stats import pearsonr

# %%
stats,p = pearsonr(solution.Attrition,solution.Age)

# %%
print(stats,p)
# Out:
# -0.1627067324180036 4.0852108430337625e-26

# %% [markdown]
# <h4>h1 is accepted:</h4>
# <h3>Attrition has significant correlation with Age</h3>
#
# p value<0.05
# i.e h0 is rejected

# %%
solution.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51         0      Travel_Rarely                   Sales                 6
# 1   31         1  Travel_Frequently  Research & Development                10
# 3   38         0         Non-Travel  Research & Development                 2
# 4   32         0      Travel_Rarely  Research & Development                10
# 5   46         0      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# 5          3  Life Sciences              1           6  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
stats,p = pearsonr(solution.Attrition,solution.DistanceFromHome)
print(stats,p)
# Out:
# -0.015272414273967822 0.3243141044286852

# %% [markdown]
# <h4>
# p-value > 0.05
#
# alternative hypothesis is accepted</h4>

# %%
stats,p = pearsonr(solution.Attrition,solution.Education)
print(stats,p)
# Out:
# -0.015618586782342545 0.3134665781063368

# %% [markdown]
# <h4>
# p-value > 0.05
#
# alternative hypothesis is accepted</h4>

# %%
stats,p = pearsonr(solution.Attrition,solution.MonthlyIncome)
print(stats,p)
# Out:
# -0.02062217633881916 0.18320508736911498

# %%
stats,p = pearsonr(solution.Attrition,solution.StockOptionLevel)
print(stats,p)
# Out:
# -0.007814665147700971 0.6140428503376113

# %%
stats,p = pearsonr(solution.Attrition,solution.YearsAtCompany)
print(stats,p)
# Out:
# -0.13856355838947015 2.5805889131648085e-19

# %%
stats,p = pearsonr(solution.Attrition,solution.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.03350735748254184 0.030546138992024328

# %%
stats,p = pearsonr(solution.Attrition,solution.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.16163227616214504 8.664298719059498e-26

# %% [markdown]
# <h3>
#     whenever we get 'p value less , we have to accept Alternative(h1) hypothesis
#     otherwise accept Null hypothesis<h3>
